# %%
# IMPLEMENT STACK USİNG QUEUES

# Implement a last-in-first-out stack using only two queues. The implemented stack should support all the functions of a normal stack
# (push, top, pop, and empty)

#

# %%
class MyStack:

    def __init__(self):
        self.myQueue = deque()

    def push(self, x: int)  
        self.myQueue.append(x)

    def pop(self):
        for i in range(len(self.myQueue) -1):
            self.myQueue.append(self.myQueue.popleft())
        return self.myQueue.popleft()  

     def top(self):
         return self.myqueue[-1]

     def empty(self):
         return len(self.myQueue) == 0
