# %%
# STACK: pythonda bunun için ayrı bir uyg. yapmaya gerek yok çünkü listeler de aynı özelliklere sahip ve aynı işleri yapıyor.

# %%
myList = []

# %%
myList.append(1)
myList.append(2)

# %%
myList
# Out:
# [1, 2]

# %%
myList.append(3)

# %%
myList
# Out:
# [1, 2, 3]

# %%
myList.pop()
# Out:
# 3

# %%
myList
# Out:
# [1, 2]

# %%
from queue import LifoQueue # stack için python da

# %%
lifoQueue = LifoQueue()

# %%
lifoQueue.put(1)

# %%
lifoQueue.put(10)

# %%
lifoQueue

# %%
lifoQueue.get() # en son eklenen neyse onu gösteriyor.
# Out:
# 10

# %%
lifoQueue.get() # bu aynı zamanda pop işlemiymiş. en son ekleneni çıkardı
# Out:
# 1

# %%
# QUEUE

# %%
from queue import Queue

# %%
myQueue = Queue()

# %%
myQueue.put(1)

# %%
myQueue.put(10)

# %%
myQueue.put(20)

# %%
myQueue.get() # ilk giren ilk çıktı FIFO
# Out:
# 1

# %%
# DEQUE

# %%
from collections import deque

# %%
myDeque = deque()

# %%
myDeque.append(10)

# %%
myDeque.append(20)

# %%
myDeque.append(30)

# %%
myDeque
# Out:
# deque([10, 20, 30])

# %%
myDeque.appendleft(40)

# %%
myDeque
# Out:
# deque([40, 10, 20, 30])

# %%
myDeque.pop()
# Out:
# 30

# %%
myDeque.popleft()
# Out:
# 40
