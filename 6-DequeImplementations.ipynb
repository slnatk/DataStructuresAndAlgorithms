# %%
'''
Deque()

addRight()
addLeft()

removeRight()
removeLeft()

isEmpty()
size()
show()


'''
# Out:
# '\nDeque()\n\naddRight()\naddLeft()\n\nremoveRight()\nremoveLeft()\n\nisEmpty()\nsize()\n\n\n'

# %%
class Deque():

    def __init__(self):
        self.elements = []

    def isEmpty(self):
        return self.elements == []

    def addRight(self,element):
        self.elements.append(element)

    def addLeft(self,element):
        self.elements.insert(0,element)

    def removeRight(self):
        return self.elements.pop() # en sondakini zaten atıyor

    def removeLeft(self):
        return self.elements.pop(0)

    def size(self):
        return len(self.elements)

    def show(self):
        return self.elements

# %%
myDeque = Deque()

# %%
myDeque.addRight(10)

# %%
myDeque.addRight(20)

# %%
# [10,20]

# %%
myDeque.addLeft(30)

# %%
#[30,10,20]

# %%
myDeque.addLeft(40)

# %%
#[40,30,10,20]

# %%
myDeque.addRight(50)

# %%
# [40,30,10,20,50]

# %%
myDeque.size()
# Out:
# 5

# %%
myDeque.show()
# Out:
# [40, 30, 10, 20, 50]

# %%
myDeque.removeLeft()
# Out:
# 40

# %%
myDeque.removeRight()
# Out:
# 50
