# %%
'''
Given an m x n 2D binary grid grid which represents a map of '1's (land) and '0's (water), return the number of islands.

An island is surrounded by water and is formed by connecting adjacent lands horizontally or vertically. You may assume all four edges of the grid are all surrounded by water.

'''
# Out:
# "\nGiven an m x n 2D binary grid grid which represents a map of '1's (land) and '0's (water), return the number of islands.\n\nAn island is surrounded by water and is formed by connecting adjacent lands horizontally or vertically. You may assume all four edges of the grid are all surrounded by water.\n\n"

# %%
# BFS: araştırırken yatay baktığımız için, dikey baksak DFS olurdu
class Solution:
    def numIslands(self, grid):
        rowNumber = len(grid)
        columnNumber = len(grid[0]) # genelde böyle bir matris görünümğ verilir ve biz de bu şekilde row ve kolonları alabilirz

        visited =  set()

        islandCounter = 0

        def bfs(row, column):
            myQueue = [] # FIFO

            visited.add((row, column))
            myQueue.append((row, column))

            while len(myQueue) != 0:
                row, column = myQueue.pop(0) # queue bir liste son elemanı atmasın queue özelliğini kullansın diye ilk elemanı atmalı o yüzden 0 dedik
                myDirections = [[1,0], [-1,0],[0,1],[0,-1]] # elemanın sağı solu aşağısı yukarısı

                for rowDirection, columnDirection in myDirections:
                    newrow = row + rowDirection
                    newColumn = column + columnDirection

                    if (newRow in range(rowNumber) and
                       newColumn in range(columnNumber) and
                       gird[newRow][newColumns] == "1" and
                       (newRow, newColumn) not in visited):
                        myQueue.append((newRow, newColumn))
                        visited.add((newRow, newColumn)) # 1 gördüklerini tekrar komşularına bakıyor ve recursive çalıştıyor.

                for row in range(rowNumber):
                    for column in range(columnNumber):
                        if grid[row][column] == "1" and (row,column) not in visited:
                            bfs(row,column)
                            islandCounter += 1

                 return islandCounter
