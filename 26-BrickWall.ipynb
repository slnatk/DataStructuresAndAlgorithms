# %%
'''
There is a rectangular brick wall in front of you with n rows of bricks. The ith row has some number of bricks each of the same height (i.e., one unit) but they can be of different widths. The total width of each row is the same.

Draw a vertical line from the top to the bottom and cross the least bricks. If your line goes through the edge of a brick, then the brick is not considered as crossed. You cannot draw a line just along one of the two vertical edges of the wall, in which case the line will obviously cross no bricks.

Given the 2D array wall that contains the information about the wall, return the minimum number of crossed bricks after drawing such a vertical line.
'''
# Out:
# '\nThere is a rectangular brick wall in front of you with n rows of bricks. The ith row has some number of bricks each of the same height (i.e., one unit) but they can be of different widths. The total width of each row is the same.\n\nDraw a vertical line from the top to the bottom and cross the least bricks. If your line goes through the edge of a brick, then the brick is not considered as crossed. You cannot draw a line just along one of the two vertical edges of the wall, in which case the line will obviously cross no bricks.\n\nGiven the 2D array wall that contains the information about the wall, return the minimum number of crossed bricks after drawing such a vertical line.\n'

# %%
# Input : wall = [[1,2,2,1],[3,1,2],[1,3,2],[2,4],[3,1,2],[1,3,1,1]]
# output: 2
# Input: wall = [[1],[1],[1]]
# output: 3

# %%
class Solution:
    def leastBricks(self, wall):
        myHashMap = {0:0} # key: ix, value: gap   , belki hiç boşluk yoksa 0 döndürebileleim diye böyle başladık
 
        for row in wall:
            gapIndex = 0
            for brick in row[:-1]: # son elemanı alma
                gapIndex += brick
                myHashMap[gapIndex] = 1 + myHashMap.get(gapIndex,0)
        maximumGapNumber = max(myHashMap.values())
        rowNumber = len(wall)
        return rowNumber - maximumGapNumber

# %%
sol = Solution()

# %%
sol.leastBricks([[1,2,2,1],[3,1,2],[1,3,2],[2,4],[3,1,2],[1,3,1,1]])
# Out:
# 2
